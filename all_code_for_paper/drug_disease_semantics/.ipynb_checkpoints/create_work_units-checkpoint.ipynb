# %% [markdown]
# ## Program for choosing random work units from the drug/disease links of the EU-ADR corpus for CrowdFlower

# %% [markdown]
# 2015-03-31 Toby

# %%
from collections import Counter
import pandas as pd
import random

random.seed()

# %%
import sys
sys.path.append("/home/toby/global_util/")
from web_util import add_simple_tag

# %% [markdown]
# Read the EU-ADR data into memory:

# %%
loc = "data/EUADR_drug_disease.csv"
data = pd.read_csv(loc, sep = "\t")

# %% [markdown]
# Change the column names:

# %%
column_names = [
    "gold_std_association_type", "pubmed_id", "num_sentence",
    "subject_text", "subject_start", "subject_end", "subject_type",
    "object_text", "object_start", "object_end", "object_type",
    "original_sentence"
]

data.columns = column_names

# %% [markdown]
# Rename the entity types to something simple:

# %%
data["subject_type"] = "disease"
data["object_type"] = "drug"

# %% [markdown]
# Now we convert the two letter association codes to something more readable. Pandas treats the "NA" in Association_type to mean "not a number", so we want to change those values to the string "negative" (association).

# %%
data = data.fillna("negative")

vals = {
    "PA": "positive",
    "FA": "false",
    "SA": "speculative",
}

for old_val, new_val in vals.items():
    data.loc[data.gold_std_association_type == old_val, ["gold_std_association_type"]] = new_val

# %%
data
# Out:
#     gold_std_association_type  pubmed_id  num_sentence  \
# 0                    positive   17897305             8
# 1                       false   18042885             0
# 2                       false   18042885             0
# 3                       false   18037672             8
# 4                       false   18037672             8
# 5                    positive   17237684            13
# 6                    positive   17940253             1
# 7                    positive   17940253             3
# 8                    positive   17940253             3
# 9                       false   17274718             2
# 10                      false   17274718             6
# 11                   positive   17274718             6
# 12                   positive   17274718             9
# 13                      false   17274718             2
# 14                   positive   17274718             2
# 15                   positive   18640477            10
# 16                      false   18640477             0
# 17                      false   18640477             5
# 18                   positive   18640477             6
# 19                   positive   18640477             9
# 20                   positive   18640477             5
# 21                   positive   18953065            12
# 22                   positive   18953065            12
# 23                   positive   18953065            12
# 24                   positive   18434457            12
# 25                   positive   18434457            12
# 26                   positive   18434457            12
# 27                   positive   18434457            12
# 28                   positive   18434457            12
# 29                   positive   18434457             8
# ..                        ...        ...           ...
# 214                  positive   18975369             7
# 215                  positive   18975369             4
# 216                  positive   18975369             6
# 217                  positive   18975369             5
# 218                  positive   18975369             5
# 219                     false   17688650             1
# 220                  positive   17688650             2
# 221                  positive   17688650             2
# 222                  negative   18609261            11
# 223                  positive   18609261            11
# 224                  positive   18560637             7
# 225                  positive   17291222             0
# 226                  positive   17291222            10
# 227                     false   17291222             3
# 228                     false   17291222             3
# 229                     false   19100448             9
# 230                  positive   19100448            10
# 231                  positive   19100448            12
# 232                     false   19100448             4
# 233                     false   19100448             4
# 234                  positive   16944312            10
# 235                     false   16944312             9
# 236                  positive   16944312             9
# 237                     false   16944312             3
# 238               speculative   17244684             1
# 239                     false   17244684             1
# 240                  positive   17244684             9
# 241                  positive   17244684             9
# 242                  positive   18398094            12
# 243                  positive   18398094            12
#
#                                       subject_text  subject_start  \
# 0                                venous thrombosis             53
# 1    Cardiovascular thromboembolic adverse effects              0
# 2    Cardiovascular thromboembolic adverse effects              0
# 3                                  motion sickness            180
# 4                                  motion sickness            180
# 5                                          dry eye            187
# 6                           neurological disorders             61
# 7                                       spasticity             97
# 8                                systemic weakness             56
# 9                              gingival overgrowth            158
# 10                                   periodontitis            128
# 11                             gingival overgrowth             75
# 12                             gingival overgrowth            107
# 13                                   periodontitis             91
# 14                             gingival overgrowth            158
# 15                                     mild asthma             95
# 16                                     mild asthma             78
# 17                                     mild asthma             92
# 18                                     mild asthma            235
# 19                                          asthma            151
# 20                               allergic rhinitis            213
# 21                             leukoencephalopathy            115
# 22                             leukoencephalopathy            115
# 23                             leukoencephalopathy            115
# 24                   anterior shoulder dislocation             66
# 25                                            pain            114
# 26                                            pain            114
# 27                   anterior shoulder dislocation             66
# 28                   anterior shoulder dislocation             66
# 29                                            pain              5
# ..                                             ...            ...
# 214                                  hyperuricemia            168
# 215                        impaired renal function             62
# 216                                    gout flares             73
# 217                                      dizziness            130
# 218                                       diarrhea            117
# 219                                 teratogenicity             16
# 220                            neural tube defects             30
# 221                       congenital malformations            100
# 222                                   hypogonadism             54
# 223                                     vasculitis            154
# 224                           autoimmune hepatitis             56
# 225                 Pulmonary alveolar proteinosis              0
# 226                                            PAP              0
# 227                            nonproductive cough             82
# 228                                     chest pain            103
# 229                            leucoencephalopathy             22
# 230                                GI side effects             41
# 231                                severe diarrhea            191
# 232                               gastrointestinal            201
# 233                               gastrointestinal            201
# 234                     hematological side effects            141
# 235                         perioperative seizures            118
# 236                         perioperative seizures            118
# 237                         perioperative seizures             94
# 238                                           GVHD            127
# 239     gastrointestinal graft-versus-host disease             83
# 240              relapses of gastrointestinal GVHD             18
# 241              relapses of gastrointestinal GVHD             18
# 242                                          edema             28
# 243                                     leukopenia             13
#
#      subject_end subject_type                             object_text  \
# 0             70      disease                     oral contraceptives
# 1             45      disease                          cyclooxygenase
# 2             45      disease     nonselective antiinflammatory drugs
# 3            195      disease                              alfentanil
# 4            195      disease                                propofol
# 5            194      disease                         botulinum toxin
# 6             83      disease                        Botulinum toxins
# 7            107      disease                  botulinum toxin type B
# 8             73      disease                  botulinum toxin type B
# 9            177      disease                                     CsA
# 10           141      disease                                     CsA
# 11            94      disease                                     CsA
# 12           126      disease                                     CsA
# 13           104      disease                                     CsA
# 14           177      disease                           cyclosporin A
# 15           106      disease                             montelukast
# 16            89      disease                             montelukast
# 17           103      disease                             montelukast
# 18           246      disease                             montelukast
# 19           157      disease                             montelukast
# 20           230      disease                             montelukast
# 21           134      disease                            procarbazine
# 22           134      disease                           high-dose MTX
# 23           134      disease                                    CCNU
# 24            95      disease  Intra-articular injection of lidocaine
# 25           118      disease                  intravenous meperidine
# 26           118      disease                                diazepam
# 27            95      disease                                diazepam
# 28            95      disease                  intravenous meperidine
# 29             9      disease               intra-articular lidocaine
# ..           ...          ...                                     ...
# 214          181      disease                              febuxostat
# 215           85      disease                             allopurinol
# 216           84      disease                              febuxostat
# 217          139      disease                              febuxostat
# 218          125      disease                              febuxostat
# 219           30      disease                     antiepileptic drugs
# 220           49      disease                     antiepileptic drugs
# 221          124      disease                     antiepileptic drugs
# 222           66      disease                        cyclophosphamide
# 223          164      disease                        cyclophosphamide
# 224           76      disease                            azathioprine
# 225           30      disease                               sirolimus
# 226            3      disease                                     SRL
# 227          101      disease                                     SRL
# 228          113      disease                                     SRL
# 229           41      disease                                     SRL
# 230           56      disease                                     MMF
# 231          206      disease                                     MMF
# 232          217      disease                                     MMF
# 233          217      disease                   mycophenolate mofetil
# 234          167      disease                           oxcarbazepine
# 235          140      disease                    antiepileptic agents
# 236          140      disease                           oxcarbazepine
# 237          116      disease                    antiepileptic agents
# 238          131      disease        oral beclomethasone dipropionate
# 239          125      disease                                     BDP
# 240           51      disease                              prednisone
# 241           51      disease                                     BDP
# 242           33      disease                                     TAC
# 243           23      disease                                     TAC
#
#      object_start  object_end object_type  \
# 0             106         125        drug
# 1              62          76        drug
# 2             104         139        drug
# 3              58          68        drug
# 4              70          78        drug
# 5              41          56        drug
# 6               0          16        drug
# 7             113         135        drug
# 8             113         135        drug
# 9             145         148        drug
# 10             63          66        drug
# 11             63          66        drug
# 12             95          98        drug
# 13            145         148        drug
# 14            130         143        drug
# 15             27          38        drug
# 16             28          39        drug
# 17            117         128        drug
# 18            171         182        drug
# 19            105         116        drug
# 20            117         128        drug
# 21             38          50        drug
# 22             19          32        drug
# 23             55          59        drug
# 24              0          38        drug
# 25            129         151        drug
# 26            156         164        drug
# 27            156         164        drug
# 28            129         151        drug
# 29             87         112        drug
# ..            ...         ...         ...
# 214            22          32        drug
# 215           256         267        drug
# 216           116         126        drug
# 217           166         176        drug
# 218           166         176        drug
# 219            34          53        drug
# 220            54          73        drug
# 221            54          73        drug
# 222            83          99        drug
# 223            83          99        drug
# 224            39          51        drug
# 225            61          70        drug
# 226            35          38        drug
# 227            27          30        drug
# 228            27          30        drug
# 229            82          85        drug
# 230            60          63        drug
# 231           214         217        drug
# 232           262         265        drug
# 233           239         260        drug
# 234            10          23        drug
# 235            76          96        drug
# 236            21          34        drug
# 237            51          71        drug
# 238            30          62        drug
# 239            64          67        drug
# 240            74          84        drug
# 241           158         161        drug
# 242           121         124        drug
# 243           121         124        drug
#
#                                      original_sentence
# 0    Body height, weight and obesity increase the r...
# 1    Cardiovascular thromboembolic adverse effects ...
# 2    Cardiovascular thromboembolic adverse effects ...
# 3    The frequency of PONV did not correlate to the...
# 4    The frequency of PONV did not correlate to the...
# 5    However, decreased tear production after botul...
# 6    Botulinum toxins are potent neurotoxins used i...
# 7    We describe the case of a 10-year-old boy who ...
# 8    We describe the case of a 10-year-old boy who ...
# 9    Gingival samples were collected from eight nor...
# 10   ET-1 mRNA expression was significantly higher ...
# 11   ET-1 mRNA expression was significantly higher ...
# 12   These results suggest that CsA can modulate th...
# 13   Gingival samples were collected from eight nor...
# 14   Gingival samples were collected from eight nor...
# 15   The evidence suggests that montelukast is an e...
# 16   Review of recent results of montelukast use as...
# 17   This article reviewed recent results from rand...
# 18   A literature search of MEDLINE was conducted t...
# 19   The results from these studies, encompassing e...
# 20   This article reviewed recent results from rand...
# 21   The combination of high-dose MTX with procarba...
# 22   The combination of high-dose MTX with procarba...
# 23   The combination of high-dose MTX with procarba...
# 24   Intra-articular injection of lidocaine before ...
# 25   Intra-articular injection of lidocaine before ...
# 26   Intra-articular injection of lidocaine before ...
# 27   Intra-articular injection of lidocaine before ...
# 28   Intra-articular injection of lidocaine before ...
# 29   Mean pain (mm) recorded before injection, befo...
# ..                                                 ...
# 214  At all doses studied, febuxostat more effectiv...
# 215  A significantly (P < 0.05) higher percentage o...
# 216  The primary reasons for withdrawal were simila...
# 217  Proportions of subjects experiencing any adver...
# 218  Proportions of subjects experiencing any adver...
# 219  The established teratogenicity of antiepilepti...
# 220  While the association between neural tube defe...
# 221  While the association between neural tube defe...
# 222  Data of our study revealed an unexpected high ...
# 223  Data of our study revealed an unexpected high ...
# 224  The patient was on corticosteroids and azathio...
# 225  Pulmonary alveolar proteinosis: a rare pulmona...
# 226  PAP is a very rare complication of SRL therapy...
# 227  Two years after initiating SRL, she presented ...
# 228  Two years after initiating SRL, she presented ...
# 229  The only patient with leucoencephalopathy show...
# 230  All patients converted to SRL because of GI si...
# 231  We concluded that conversion to SRL in pancrea...
# 232  The reasons for conversion were calcineurin in...
# 233  The reasons for conversion were calcineurin in...
# 234  Moreover, oxcarbazepine can be a valid choice ...
# 235  Our data showed that oxcarbazepine can be a go...
# 236  Our data showed that oxcarbazepine can be a go...
# 237  Furthermore, the efficacy of the new generatio...
# 238  We tested the hypothesis that oral beclomethas...
# 239  We tested the hypothesis that oral beclomethas...
# 240  Oral BDP prevents relapses of gastrointestinal...
# 241  Oral BDP prevents relapses of gastrointestinal...
# 242  Grade 3 or 4 leukopenia and edema and various ...
# 243  Grade 3 or 4 leukopenia and edema and various ...
#
# [244 rows x 12 columns]

# %%
temp = data.query("num_sentence == 0")
len(temp)
# Out:
# 22

# %%
Counter(temp["gold_std_association_type"])
# Out:
# Counter({'positive': 12, 'false': 10})

# %%
temp
# Out:
#     gold_std_association_type  pubmed_id  num_sentence  \
# 1                       false   18042885             0
# 2                       false   18042885             0
# 16                      false   18640477             0
# 33                   positive   18371953             0
# 37                      false   18371953             0
# 46                   positive   17483062             0
# 53                   positive   17976209             0
# 68                      false   18452197             0
# 69                   positive   18452197             0
# 82                   positive   17167348             0
# 87                      false   17340045             0
# 88                      false   17340045             0
# 91                      false   17989313             0
# 127                  positive   18230056             0
# 141                  positive   17391803             0
# 166                  positive   18512713             0
# 169                  positive   18512713             0
# 170                  positive   18512713             0
# 183                     false   18533797             0
# 197                  positive   18077493             0
# 198                     false   18077493             0
# 225                  positive   17291222             0
#
#                                       subject_text  subject_start  \
# 1    Cardiovascular thromboembolic adverse effects              0
# 2    Cardiovascular thromboembolic adverse effects              0
# 16                                     mild asthma             78
# 33                                          glioma             96
# 37                                          glioma             96
# 46             visceral varicella-zoster infection             84
# 53                                 Keratoacanthoma              0
# 68                                         colitis            138
# 69        colitis-associated colorectal dysplasias             31
# 82                          Spinal cord infarction              0
# 87                                     sarcoidosis             15
# 88                            rheumatoid arthritis             49
# 91                                multiple myeloma            173
# 127      infections due to Gram-positive pathogens             55
# 141      advanced-stage non-small-cell lung cancer             59
# 166                           rheumatoid arthritis             51
# 169                                   malignancies             32
# 170                                       melanoma             13
# 183                                         anemia             98
# 197                                   hypertension             73
# 198                           rheumatoid arthritis            103
# 225                 Pulmonary alveolar proteinosis              0
#
#      subject_end subject_type                                   object_text  \
# 1             45      disease                                cyclooxygenase
# 2             45      disease           nonselective antiinflammatory drugs
# 16            89      disease                                   montelukast
# 33           102      disease                                  indomethacin
# 37           102      disease  indomethacin ethyl ester-loaded nanocapsules
# 46           119      disease                         intravenous acyclovir
# 53            15      disease                           red dye of a tattoo
# 68           145      disease                                  azoxymethane
# 69            71      disease                         5-aminosalicylic acid
# 82            22      disease                                       cocaine
# 87            26      disease                                    etanercept
# 88            69      disease                                    etanercept
# 91           189      disease                                          BiRD
# 127           96      disease                                   Oritavancin
# 141          100      disease                                     docetaxel
# 166           71      disease                                  methotrexate
# 169           44      disease                                  methotrexate
# 170           21      disease                                  methotrexate
# 183          104      disease                                  Epoetin beta
# 197           85      disease                    medium-dose glucocorticoid
# 198          123      disease                    medium-dose glucocorticoid
# 225           30      disease                                     sirolimus
#
#      object_start  object_end object_type  \
# 1              62          76        drug
# 2             104         139        drug
# 16             28          39        drug
# 33             26          38        drug
# 37             43          87        drug
# 46            137         158        drug
# 53             37          56        drug
# 68             94         106        drug
# 69              0          21        drug
# 82             36          43        drug
# 87             30          40        drug
# 88             30          40        drug
# 91              0           4        drug
# 127             0          11        drug
# 141            45          54        drug
# 166            94         106        drug
# 169            94         106        drug
# 170            94         106        drug
# 183             0          12        drug
# 197            22          48        drug
# 198            22          48        drug
# 225            61          70        drug
#
#                                      original_sentence
# 1    Cardiovascular thromboembolic adverse effects ...
# 2    Cardiovascular thromboembolic adverse effects ...
# 16   Review of recent results of montelukast use as...
# 33   Selective cytotoxicity of indomethacin and ind...
# 37   Selective cytotoxicity of indomethacin and ind...
# 46   Quantification of circulating varicella-zoster...
# 53   Keratoacanthoma occurring within the red dye o...
# 68   5-aminosalicylic acid inhibits colitis-associa...
# 69   5-aminosalicylic acid inhibits colitis-associa...
# 82    Spinal cord infarction secondary to cocaine use.
# 87   Development of sarcoidosis in etanercept-treat...
# 88   Development of sarcoidosis in etanercept-treat...
# 91   BiRD (Biaxin [clarithromycin]/Revlimid [lenali...
# 127  Oritavancin: a new promising agent in the trea...
# 141  An open multicenter phase II trial of weekly d...
# 166  Incidence of melanoma and other malignancies a...
# 169  Incidence of melanoma and other malignancies a...
# 170  Incidence of melanoma and other malignancies a...
# 183  Epoetin beta once weekly: review of its effica...
# 197  Long-term exposure to medium-dose glucocortico...
# 198  Long-term exposure to medium-dose glucocortico...
# 225  Pulmonary alveolar proteinosis: a rare pulmona...

# %% [markdown]
# We want to include the 10 rows of data from the first test we ran, to see how the performance changed over time.

# %%
old = pd.read_csv("data/old_test_data.csv", sep = "\t")

# %%
Counter(old
# Out:
#    pubmed_id true_relation_type  \
# 0   18371953                 PA
# 1   18037672                 FA
# 2   18586644                 FA
# 3   18512713                 PA
# 4   18371953                 PA
# 5   17547473                 FA
# 6   17244684                 SA
# 7   18303032                 PA
# 8   18713852                 PA
# 9   17894421                 FA
#
#                                         subject_text subject_type  \
# 0  &quot;<span class="subject_text" id="" style="...      disease
# 1  &quot;<span class="subject_text" id="" style="...      disease
# 2  &quot;<span class="subject_text" id="" style="...      disease
# 3  &quot;<span class="subject_text" id="" style="...      disease
# 4  &quot;<span class="subject_text" id="" style="...      disease
# 5  &quot;<span class="subject_text" id="" style="...      disease
# 6  &quot;<span class="subject_text" id="" style="...      disease
# 7  &quot;<span class="subject_text" id="" style="...      disease
# 8  &quot;<span class="subject_text" id="" style="...      disease
# 9  &quot;<span class="subject_text" id="" style="...      disease
#
#    subject_start  subject_end  \
# 0            193          199
# 1            180          195
# 2            116          138
# 3             44           64
# 4            138          144
# 5            159          181
# 6            127          131
# 7             95           99
# 8             52           78
# 9             58           71
#
#                                          object_text object_type  \
# 0  &quot;<span class="object_text" id="" style="d...        drug
# 1  &quot;<span class="object_text" id="" style="d...        drug
# 2  &quot;<span class="object_text" id="" style="d...        drug
# 3  &quot;<span class="object_text" id="" style="d...        drug
# 4  &quot;<span class="object_text" id="" style="d...        drug
# 5  &quot;<span class="object_text" id="" style="d...        drug
# 6  &quot;<span class="object_text" id="" style="d...        drug
# 7  &quot;<span class="object_text" id="" style="d...        drug
# 8  &quot;<span class="object_text" id="" style="d...        drug
# 9  &quot;<span class="object_text" id="" style="d...        drug
#
#    object_start  object_end                                 formatted_sentence
# 0            46          78  <div class="formatted_sentence" id="" style="d...
# 1            58          68  <div class="formatted_sentence" id="" style="d...
# 2            67          76  <div class="formatted_sentence" id="" style="d...
# 3            92         104  <div class="formatted_sentence" id="" style="d...
# 4            90         134  <div class="formatted_sentence" id="" style="d...
# 5            54          64  <div class="formatted_sentence" id="" style="d...
# 6            30          62  <div class="formatted_sentence" id="" style="d...
# 7           198         209  <div class="formatted_sentence" id="" style="d...
# 8           183         195  <div class="formatted_sentence" id="" style="d...
# 9            16          19  <div class="formatted_sentence" id="" style="d...

# %% [markdown]
# Find the indicies of the old rows of data.

# %%
old_indicies = []
for index, row in old.iterrows():
    sub = data.query("pubmed_id == {0}".format(row["pubmed_id"]))
    sub = sub.query("subject_start == {0}".format(row["subject_start"]))
    sub = sub.query("object_start == {0}".format(row["object_start"]))
    old_indicies += [sub.index.values[0]]
    
print old_indicies
# Out:
# [34, 3, 132, 167, 41, 202, 238, 148, 100, 124]

# %% [markdown]
# What is the distribution of positive/false/speculative/negative answers in the gold standard?

# %%
Counter(data["gold_std_association_type"])
# Out:
# Counter({'positive': 162, 'false': 68, 'speculative': 12, 'negative': 2})

# %%
print "Total rows of data:", len(data)
# Out:
# Total rows of data: 244

# %% [markdown]
# We are going to arbitrarily choose 50 rows of data to give to the Crowd.

# %%
def random_rows(data_frame, n):
    all_indicies = set(old_indicies)
    while len(all_indicies) < n:
        all_indicies.add(random.sample(data_frame.index, 1)[0])
        
    return data_frame.ix[all_indicies]

# %%
num_work_units = 60
work_units = random_rows(data, num_work_units)

# %%
len(work_units)
# Out:
# 60

# %%
work_units.index.values
# Out:
# array([  1,   3, 132,  10, 139,  13,  16,  17, 146, 147, 148,  24, 157,
#         69,  33,  34,  99, 166, 167,  41, 159, 173,  11, 176, 178,  55,
#        184, 185, 187, 190,  64, 194, 195, 196, 197, 225, 202, 206,  80,
#         83,  86,  57, 216,  93, 223,  97, 226, 227, 100, 102, 107, 238,
#        111, 240, 113, 211, 122, 124, 125, 126])

# %%
work_units
# Out:
#     gold_std_association_type  pubmed_id  num_sentence  \
# 1                       false   18042885             0
# 3                       false   18037672             8
# 132                     false   18586644             8
# 10                      false   17274718             6
# 139                  positive   18058121             7
# 13                      false   17274718             2
# 16                      false   18640477             0
# 17                      false   18640477             5
# 146                  positive   18303032             2
# 147                  positive   18303032             2
# 148                  positive   18303032             2
# 24                   positive   18434457            12
# 157                  positive   17562245             1
# 69                   positive   18452197             0
# 33                   positive   18371953             0
# 34                   positive   18371953             7
# 99                   positive   18713852             8
# 166                  positive   18512713             0
# 167                  positive   18512713             1
# 41                   positive   18371953             4
# 159                  positive   18512713             9
# 173                     false   18389682             2
# 11                   positive   17274718             6
# 176                  positive   17945482             8
# 178                  positive   17945482             8
# 55                speculative   18300089            11
# 184                  positive   18790215             5
# 185                  positive   18790215             5
# 187                  positive   18790215             5
# 190                  positive   17697016             8
# 64                   positive   18342498             1
# 194                  positive   18713156             7
# 195                  positive   18713156             5
# 196                  positive   18713156             5
# 197                  positive   18077493             0
# 225                  positive   17291222             0
# 202                     false   17547473             7
# 206                  positive   17726209             5
# 80                      false   18452197             2
# 83                   positive   17167348             8
# 86                      false   17340045             9
# 57                      false   18300089             7
# 216                  positive   18975369             6
# 93                   positive   17989313            10
# 223                  positive   18609261            11
# 97                   positive   18713852            12
# 226                  positive   17291222            10
# 227                     false   17291222             3
# 100                  positive   18713852             8
# 102                  positive   18713852            12
# 107               speculative   18713852            14
# 238               speculative   17244684             1
# 111                  positive   18713852             7
# 240                  positive   17244684             9
# 113                  positive   18713852             7
# 211                  positive   18975369             6
# 122                     false   17894421             1
# 124                     false   17894421            11
# 125                     false   17894421             1
# 126                  negative   19117254            12
#
#                                         subject_text  subject_start  \
# 1      Cardiovascular thromboembolic adverse effects              0
# 3                                    motion sickness            180
# 132                           iron-deficiency anemia            116
# 10                                     periodontitis            128
# 139                            spontaneous abortions            130
# 13                                     periodontitis             91
# 16                                       mild asthma             78
# 17                                       mild asthma             92
# 146                                             PTCL             95
# 147                                             PTCL             95
# 148                                             PTCL             95
# 24                     anterior shoulder dislocation             66
# 157                  high-grade non-Hodgkin lymphoma            179
# 69          colitis-associated colorectal dysplasias             31
# 33                                            glioma             96
# 34                                            glioma            193
# 99                                     aspergillosis            105
# 166                             rheumatoid arthritis             51
# 167                             rheumatoid arthritis             44
# 41                                            glioma            138
# 159                                      lung cancer            140
# 173                                  thromboembolism            210
# 11                               gingival overgrowth             75
# 176                                      lung cancer            213
# 178                                            NSCLC             40
# 55                                      fatal cancer            159
# 184                                immunosuppression            116
# 185                                immunosuppression            116
# 187                                immunosuppression            116
# 190                                          anaemia             47
# 64                                            asthma            105
# 194                                migraine headache             97
# 195                                         headache            158
# 196                                         migraine             81
# 197                                     hypertension             73
# 225                   Pulmonary alveolar proteinosis              0
# 202                           coronary heart disease            159
# 206  stomal varices secondary to portal hypertension             68
# 80                      colitis-associated neoplasia            138
# 83                            cerebrovascular events             33
# 86             noninfectious granulomatous syndromes             37
# 57                               ocular inflammation            155
# 216                                      gout flares             73
# 93                                  multiple myeloma            107
# 223                                       vasculitis            154
# 97                                          diarrhea            119
# 226                                              PAP              0
# 227                              nonproductive cough             82
# 100                       invasive fungal infections             52
# 102                                         vomiting            105
# 107                             resistant infections            163
# 238                                             GVHD            127
# 111                       invasive fungal infections             69
# 240                relapses of gastrointestinal GVHD             18
# 113                       invasive fungal infections             69
# 211                                      gout flares             73
# 122                                 orofacial clefts            156
# 124                                    preterm birth             58
# 125                                 orofacial clefts            156
# 126                                 vascular lesions            100
#
#      subject_end subject_type                                   object_text  \
# 1             45      disease                                cyclooxygenase
# 3            195      disease                                    alfentanil
# 132          138      disease                                     NaFe-EDTA
# 10           141      disease                                           CsA
# 139          151      disease                                 radioisotopes
# 13           104      disease                                           CsA
# 16            89      disease                                   montelukast
# 17           103      disease                                   montelukast
# 146           99      disease                                     cisplatin
# 147           99      disease                                    prednisone
# 148           99      disease                                   vincristine
# 24            95      disease        Intra-articular injection of lidocaine
# 157          210      disease                              cyclophosphamide
# 69            71      disease                         5-aminosalicylic acid
# 33           102      disease                                  indomethacin
# 34           199      disease              indomethacin-loaded nanocapsules
# 99           118      disease                                  itraconazole
# 166           71      disease                                  methotrexate
# 167           64      disease                                  methotrexate
# 41           144      disease  indomethacin ethyl ester-loaded nanocapsules
# 159          151      disease                                  methotrexate
# 173          225      disease                                 anticoagulant
# 11            94      disease                                           CsA
# 176          224      disease                                        sutent
# 178           45      disease                                        sutent
# 55           171      disease                       immunosuppressive drugs
# 184          133      disease                         mycophenolate mofetil
# 185          133      disease                                    tacrolimus
# 187          133      disease                                  cyclosporine
# 190           54      disease                                    Zidovudine
# 64           111      disease                                          ICSs
# 194          114      disease                                    topiramate
# 195          166      disease                                    topiramate
# 196           89      disease                                    topiramate
# 197           85      disease                    medium-dose glucocorticoid
# 225           30      disease                                     sirolimus
# 202          181      disease                                    amlodipine
# 206          115      disease                                silver nitrate
# 80           166      disease                                           DSS
# 83            55      disease                                       Cocaine
# 86            74      disease                                    etanercept
# 57           174      disease                             alkylating agents
# 216           84      disease                                    febuxostat
# 93           123      disease                                          BiRD
# 223          164      disease                              cyclophosphamide
# 97           127      disease                                  posaconazole
# 226            3      disease                                           SRL
# 227          101      disease                                           SRL
# 100           78      disease                                  itraconazole
# 102          113      disease                                  posaconazole
# 107          183      disease                                  posaconazole
# 238          131      disease              oral beclomethasone dipropionate
# 111           95      disease                                  Posaconazole
# 240           51      disease                                    prednisone
# 113           95      disease                                   fluconazole
# 211           84      disease                                   allopurinol
# 122          172      disease                               Benzodiazepines
# 124           71      disease                                           BZD
# 125          172      disease                                           BZD
# 126          116      disease                                  etonogestrel
#
#      object_start  object_end object_type  \
# 1              62          76        drug
# 3              58          68        drug
# 132            67          76        drug
# 10             63          66        drug
# 139            60          73        drug
# 13            145         148        drug
# 16             28          39        drug
# 17            117         128        drug
# 146           270         279        drug
# 147           296         306        drug
# 148           198         209        drug
# 24              0          38        drug
# 157            46          62        drug
# 69              0          21        drug
# 33             26          38        drug
# 34             46          78        drug
# 99            183         195        drug
# 166            94         106        drug
# 167            92         104        drug
# 41             90         134        drug
# 159            38          50        drug
# 173           105         118        drug
# 11             63          66        drug
# 176            88          94        drug
# 178            88          94        drug
# 55             75          98        drug
# 184            56          77        drug
# 185            28          38        drug
# 187            42          54        drug
# 190             0          10        drug
# 64             66          70        drug
# 194            43          53        drug
# 195            14          24        drug
# 196            14          24        drug
# 197            22          48        drug
# 225            61          70        drug
# 202            54          64        drug
# 206           174         188        drug
# 80            125         128        drug
# 83              0           7        drug
# 86             97         107        drug
# 57             48          65        drug
# 216           116         126        drug
# 93              0           4        drug
# 223            83          99        drug
# 97             59          71        drug
# 226            35          38        drug
# 227            27          30        drug
# 100           183         195        drug
# 102            59          71        drug
# 107            14          26        drug
# 238            30          62        drug
# 111             0          12        drug
# 240            74          84        drug
# 113           274         285        drug
# 211           137         148        drug
# 122            12          27        drug
# 124            16          19        drug
# 125            29          32        drug
# 126           141         153        drug
#
#                                      original_sentence
# 1    Cardiovascular thromboembolic adverse effects ...
# 3    The frequency of PONV did not correlate to the...
# 132  No significant differences were observed betwe...
# 10   ET-1 mRNA expression was significantly higher ...
# 139  For exposure levels within standard recommende...
# 13   Gingival samples were collected from eight nor...
# 16   Review of recent results of montelukast use as...
# 17   This article reviewed recent results from rand...
# 146  Forty-one patients [30 males and 11 females, m...
# 147  Forty-one patients [30 males and 11 females, m...
# 148  Forty-one patients [30 males and 11 females, m...
# 24   Intra-articular injection of lidocaine before ...
# 157  Administration of full-dose R-CHOP (rituximab/...
# 69   5-aminosalicylic acid inhibits colitis-associa...
# 33   Selective cytotoxicity of indomethacin and ind...
# 34   The main finding of the present study is that ...
# 99   Similarly, the same regimen of posaconazole re...
# 166  Incidence of melanoma and other malignancies a...
# 167  To determine cancer risk in a cohort of 459 rh...
# 41   The aim of this study was to evaluate the effe...
# 159  Compared with the general population, methotre...
# 173  Dental surgery for these children has historic...
# 11   ET-1 mRNA expression was significantly higher ...
# 176  Finally, in non-small cell lung cancer (NSCLC)...
# 178  Finally, in non-small cell lung cancer (NSCLC)...
# 55   Information from the SITE Cohort Study should ...
# 184  During the induction phase, tacrolimus or cycl...
# 185  During the induction phase, tacrolimus or cycl...
# 187  During the induction phase, tacrolimus or cycl...
# 190  Zidovudine discontinuation could help to avoid...
# 64   There is evidence in the literature that inhal...
# 194  This study demonstrated that both low-dose top...
# 195  Results - The topiramate group showed a reduct...
# 196  Results - The topiramate group showed a reduct...
# 197  Long-term exposure to medium-dose glucocortico...
# 225  Pulmonary alveolar proteinosis: a rare pulmona...
# 202  Compared with both diuretics and contemporary ...
# 206  All three patients had recurrent admissions fo...
# 80   The chemopreventive activity of 5-ASA was eval...
# 83   Cocaine abuse is associated with cerebrovascul...
# 86   Recently, there have been reports of noninfect...
# 57   Past use of antimetabolites, T-cell inhibitors...
# 216  The primary reasons for withdrawal were simila...
# 93   BiRD is an effective regimen with manageable s...
# 223  Data of our study revealed an unexpected high ...
# 97   The most common adverse effects associated wit...
# 226  PAP is a very rare complication of SRL therapy...
# 227  Two years after initiating SRL, she presented ...
# 100  Similarly, the same regimen of posaconazole re...
# 102  The most common adverse effects associated wit...
# 107  At this time, posaconazole should probably be ...
# 238  We tested the hypothesis that oral beclomethas...
# 111  Posaconazole, in doses of 200 mg 3 times daily...
# 240  Oral BDP prevents relapses of gastrointestinal...
# 113  Posaconazole, in doses of 200 mg 3 times daily...
# 211  The primary reasons for withdrawal were simila...
# 122  Exposure to Benzodiazepines (BZD) during foeta...
# 124  Maternal use of BZD and/or HBRA may increase t...
# 125  Exposure to Benzodiazepines (BZD) during foeta...
# 126  We found no evidence of impaired control of th...

# %%
work_units.loc[old_indicies, "data_subset"] = "old"
work_units.loc[list(set(work_units.index.values) - set(old_indicies)), "data_subset"] = "new"

# %%
work_units
# Out:
#     gold_std_association_type  pubmed_id  num_sentence  \
# 1                       false   18042885             0
# 3                       false   18037672             8
# 132                     false   18586644             8
# 10                      false   17274718             6
# 139                  positive   18058121             7
# 13                      false   17274718             2
# 16                      false   18640477             0
# 17                      false   18640477             5
# 146                  positive   18303032             2
# 147                  positive   18303032             2
# 148                  positive   18303032             2
# 24                   positive   18434457            12
# 157                  positive   17562245             1
# 69                   positive   18452197             0
# 33                   positive   18371953             0
# 34                   positive   18371953             7
# 99                   positive   18713852             8
# 166                  positive   18512713             0
# 167                  positive   18512713             1
# 41                   positive   18371953             4
# 159                  positive   18512713             9
# 173                     false   18389682             2
# 11                   positive   17274718             6
# 176                  positive   17945482             8
# 178                  positive   17945482             8
# 55                speculative   18300089            11
# 184                  positive   18790215             5
# 185                  positive   18790215             5
# 187                  positive   18790215             5
# 190                  positive   17697016             8
# 64                   positive   18342498             1
# 194                  positive   18713156             7
# 195                  positive   18713156             5
# 196                  positive   18713156             5
# 197                  positive   18077493             0
# 225                  positive   17291222             0
# 202                     false   17547473             7
# 206                  positive   17726209             5
# 80                      false   18452197             2
# 83                   positive   17167348             8
# 86                      false   17340045             9
# 57                      false   18300089             7
# 216                  positive   18975369             6
# 93                   positive   17989313            10
# 223                  positive   18609261            11
# 97                   positive   18713852            12
# 226                  positive   17291222            10
# 227                     false   17291222             3
# 100                  positive   18713852             8
# 102                  positive   18713852            12
# 107               speculative   18713852            14
# 238               speculative   17244684             1
# 111                  positive   18713852             7
# 240                  positive   17244684             9
# 113                  positive   18713852             7
# 211                  positive   18975369             6
# 122                     false   17894421             1
# 124                     false   17894421            11
# 125                     false   17894421             1
# 126                  negative   19117254            12
#
#                                         subject_text  subject_start  \
# 1      Cardiovascular thromboembolic adverse effects              0
# 3                                    motion sickness            180
# 132                           iron-deficiency anemia            116
# 10                                     periodontitis            128
# 139                            spontaneous abortions            130
# 13                                     periodontitis             91
# 16                                       mild asthma             78
# 17                                       mild asthma             92
# 146                                             PTCL             95
# 147                                             PTCL             95
# 148                                             PTCL             95
# 24                     anterior shoulder dislocation             66
# 157                  high-grade non-Hodgkin lymphoma            179
# 69          colitis-associated colorectal dysplasias             31
# 33                                            glioma             96
# 34                                            glioma            193
# 99                                     aspergillosis            105
# 166                             rheumatoid arthritis             51
# 167                             rheumatoid arthritis             44
# 41                                            glioma            138
# 159                                      lung cancer            140
# 173                                  thromboembolism            210
# 11                               gingival overgrowth             75
# 176                                      lung cancer            213
# 178                                            NSCLC             40
# 55                                      fatal cancer            159
# 184                                immunosuppression            116
# 185                                immunosuppression            116
# 187                                immunosuppression            116
# 190                                          anaemia             47
# 64                                            asthma            105
# 194                                migraine headache             97
# 195                                         headache            158
# 196                                         migraine             81
# 197                                     hypertension             73
# 225                   Pulmonary alveolar proteinosis              0
# 202                           coronary heart disease            159
# 206  stomal varices secondary to portal hypertension             68
# 80                      colitis-associated neoplasia            138
# 83                            cerebrovascular events             33
# 86             noninfectious granulomatous syndromes             37
# 57                               ocular inflammation            155
# 216                                      gout flares             73
# 93                                  multiple myeloma            107
# 223                                       vasculitis            154
# 97                                          diarrhea            119
# 226                                              PAP              0
# 227                              nonproductive cough             82
# 100                       invasive fungal infections             52
# 102                                         vomiting            105
# 107                             resistant infections            163
# 238                                             GVHD            127
# 111                       invasive fungal infections             69
# 240                relapses of gastrointestinal GVHD             18
# 113                       invasive fungal infections             69
# 211                                      gout flares             73
# 122                                 orofacial clefts            156
# 124                                    preterm birth             58
# 125                                 orofacial clefts            156
# 126                                 vascular lesions            100
#
#      subject_end subject_type                                   object_text  \
# 1             45      disease                                cyclooxygenase
# 3            195      disease                                    alfentanil
# 132          138      disease                                     NaFe-EDTA
# 10           141      disease                                           CsA
# 139          151      disease                                 radioisotopes
# 13           104      disease                                           CsA
# 16            89      disease                                   montelukast
# 17           103      disease                                   montelukast
# 146           99      disease                                     cisplatin
# 147           99      disease                                    prednisone
# 148           99      disease                                   vincristine
# 24            95      disease        Intra-articular injection of lidocaine
# 157          210      disease                              cyclophosphamide
# 69            71      disease                         5-aminosalicylic acid
# 33           102      disease                                  indomethacin
# 34           199      disease              indomethacin-loaded nanocapsules
# 99           118      disease                                  itraconazole
# 166           71      disease                                  methotrexate
# 167           64      disease                                  methotrexate
# 41           144      disease  indomethacin ethyl ester-loaded nanocapsules
# 159          151      disease                                  methotrexate
# 173          225      disease                                 anticoagulant
# 11            94      disease                                           CsA
# 176          224      disease                                        sutent
# 178           45      disease                                        sutent
# 55           171      disease                       immunosuppressive drugs
# 184          133      disease                         mycophenolate mofetil
# 185          133      disease                                    tacrolimus
# 187          133      disease                                  cyclosporine
# 190           54      disease                                    Zidovudine
# 64           111      disease                                          ICSs
# 194          114      disease                                    topiramate
# 195          166      disease                                    topiramate
# 196           89      disease                                    topiramate
# 197           85      disease                    medium-dose glucocorticoid
# 225           30      disease                                     sirolimus
# 202          181      disease                                    amlodipine
# 206          115      disease                                silver nitrate
# 80           166      disease                                           DSS
# 83            55      disease                                       Cocaine
# 86            74      disease                                    etanercept
# 57           174      disease                             alkylating agents
# 216           84      disease                                    febuxostat
# 93           123      disease                                          BiRD
# 223          164      disease                              cyclophosphamide
# 97           127      disease                                  posaconazole
# 226            3      disease                                           SRL
# 227          101      disease                                           SRL
# 100           78      disease                                  itraconazole
# 102          113      disease                                  posaconazole
# 107          183      disease                                  posaconazole
# 238          131      disease              oral beclomethasone dipropionate
# 111           95      disease                                  Posaconazole
# 240           51      disease                                    prednisone
# 113           95      disease                                   fluconazole
# 211           84      disease                                   allopurinol
# 122          172      disease                               Benzodiazepines
# 124           71      disease                                           BZD
# 125          172      disease                                           BZD
# 126          116      disease                                  etonogestrel
#
#      object_start  object_end object_type  \
# 1              62          76        drug
# 3              58          68        drug
# 132            67          76        drug
# 10             63          66        drug
# 139            60          73        drug
# 13            145         148        drug
# 16             28          39        drug
# 17            117         128        drug
# 146           270         279        drug
# 147           296         306        drug
# 148           198         209        drug
# 24              0          38        drug
# 157            46          62        drug
# 69              0          21        drug
# 33             26          38        drug
# 34             46          78        drug
# 99            183         195        drug
# 166            94         106        drug
# 167            92         104        drug
# 41             90         134        drug
# 159            38          50        drug
# 173           105         118        drug
# 11             63          66        drug
# 176            88          94        drug
# 178            88          94        drug
# 55             75          98        drug
# 184            56          77        drug
# 185            28          38        drug
# 187            42          54        drug
# 190             0          10        drug
# 64             66          70        drug
# 194            43          53        drug
# 195            14          24        drug
# 196            14          24        drug
# 197            22          48        drug
# 225            61          70        drug
# 202            54          64        drug
# 206           174         188        drug
# 80            125         128        drug
# 83              0           7        drug
# 86             97         107        drug
# 57             48          65        drug
# 216           116         126        drug
# 93              0           4        drug
# 223            83          99        drug
# 97             59          71        drug
# 226            35          38        drug
# 227            27          30        drug
# 100           183         195        drug
# 102            59          71        drug
# 107            14          26        drug
# 238            30          62        drug
# 111             0          12        drug
# 240            74          84        drug
# 113           274         285        drug
# 211           137         148        drug
# 122            12          27        drug
# 124            16          19        drug
# 125            29          32        drug
# 126           141         153        drug
#
#                                      original_sentence data_subset
# 1    Cardiovascular thromboembolic adverse effects ...         new
# 3    The frequency of PONV did not correlate to the...         old
# 132  No significant differences were observed betwe...         old
# 10   ET-1 mRNA expression was significantly higher ...         new
# 139  For exposure levels within standard recommende...         new
# 13   Gingival samples were collected from eight nor...         new
# 16   Review of recent results of montelukast use as...         new
# 17   This article reviewed recent results from rand...         new
# 146  Forty-one patients [30 males and 11 females, m...         new
# 147  Forty-one patients [30 males and 11 females, m...         new
# 148  Forty-one patients [30 males and 11 females, m...         old
# 24   Intra-articular injection of lidocaine before ...         new
# 157  Administration of full-dose R-CHOP (rituximab/...         new
# 69   5-aminosalicylic acid inhibits colitis-associa...         new
# 33   Selective cytotoxicity of indomethacin and ind...         new
# 34   The main finding of the present study is that ...         old
# 99   Similarly, the same regimen of posaconazole re...         new
# 166  Incidence of melanoma and other malignancies a...         new
# 167  To determine cancer risk in a cohort of 459 rh...         old
# 41   The aim of this study was to evaluate the effe...         old
# 159  Compared with the general population, methotre...         new
# 173  Dental surgery for these children has historic...         new
# 11   ET-1 mRNA expression was significantly higher ...         new
# 176  Finally, in non-small cell lung cancer (NSCLC)...         new
# 178  Finally, in non-small cell lung cancer (NSCLC)...         new
# 55   Information from the SITE Cohort Study should ...         new
# 184  During the induction phase, tacrolimus or cycl...         new
# 185  During the induction phase, tacrolimus or cycl...         new
# 187  During the induction phase, tacrolimus or cycl...         new
# 190  Zidovudine discontinuation could help to avoid...         new
# 64   There is evidence in the literature that inhal...         new
# 194  This study demonstrated that both low-dose top...         new
# 195  Results - The topiramate group showed a reduct...         new
# 196  Results - The topiramate group showed a reduct...         new
# 197  Long-term exposure to medium-dose glucocortico...         new
# 225  Pulmonary alveolar proteinosis: a rare pulmona...         new
# 202  Compared with both diuretics and contemporary ...         old
# 206  All three patients had recurrent admissions fo...         new
# 80   The chemopreventive activity of 5-ASA was eval...         new
# 83   Cocaine abuse is associated with cerebrovascul...         new
# 86   Recently, there have been reports of noninfect...         new
# 57   Past use of antimetabolites, T-cell inhibitors...         new
# 216  The primary reasons for withdrawal were simila...         new
# 93   BiRD is an effective regimen with manageable s...         new
# 223  Data of our study revealed an unexpected high ...         new
# 97   The most common adverse effects associated wit...         new
# 226  PAP is a very rare complication of SRL therapy...         new
# 227  Two years after initiating SRL, she presented ...         new
# 100  Similarly, the same regimen of posaconazole re...         old
# 102  The most common adverse effects associated wit...         new
# 107  At this time, posaconazole should probably be ...         new
# 238  We tested the hypothesis that oral beclomethas...         old
# 111  Posaconazole, in doses of 200 mg 3 times daily...         new
# 240  Oral BDP prevents relapses of gastrointestinal...         new
# 113  Posaconazole, in doses of 200 mg 3 times daily...         new
# 211  The primary reasons for withdrawal were simila...         new
# 122  Exposure to Benzodiazepines (BZD) during foeta...         new
# 124  Maternal use of BZD and/or HBRA may increase t...         old
# 125  Exposure to Benzodiazepines (BZD) during foeta...         new
# 126  We found no evidence of impaired control of th...         new

# %% [markdown]
# Let's see if we get a good distribution of positive/speculative/negative/false answers in the work that we will be giving to the crowd:

# %%
Counter(work_units["gold_std_association_type"])
# Out:
# Counter({'positive': 40, 'false': 16, 'speculative': 3, 'negative': 1})

# %%
def highlight_concepts(text, sub_text, obj_text):
    if text == sub_text:
        return add_simple_tag("span", "subject_text", text)
    
    if text == obj_text:
        return add_simple_tag("span", "object_text", text)
    
    return text

def highlight_sentence(row):
    """
    Generates the highlighted sentence for Crowdflower
    given one single dataframe row.
    """
    positions = sorted([0, len(row["original_sentence"]),
                        row["subject_start"], row["subject_end"],
                        row["object_start"], row["object_end"]])
    
    sentence = row["original_sentence"]
    
    temp = []
    for i in range(len(positions) - 1):
        temp += highlight_concepts(sentence[positions[i] : positions[i+1]],
                                   row["subject_text"], row["object_text"])
        
    return add_simple_tag("div", "formatted_sentence", "".join(temp))
    
    
sentences = work_units.apply(highlight_sentence, axis = 1)

work_units["formatted_sentence"] = sentences

# %%
def format_subject(text):
    return "&quot;{0}&quot;".format(add_simple_tag("span", "form_subject", text))

def format_object(text):
    return "&quot;{0}&quot;".format(add_simple_tag("span", "form_object", text))

# %%
form_subject = work_units["subject_text"].apply(format_subject)
form_object = work_units["object_text"].apply(format_object)

# %%
work_units["form_subject"] = form_subject
work_units["form_object"] = form_object

# %%
work_units
# Out:
#     gold_std_association_type  pubmed_id  num_sentence  \
# 1                       false   18042885             0
# 3                       false   18037672             8
# 132                     false   18586644             8
# 10                      false   17274718             6
# 139                  positive   18058121             7
# 13                      false   17274718             2
# 16                      false   18640477             0
# 17                      false   18640477             5
# 146                  positive   18303032             2
# 147                  positive   18303032             2
# 148                  positive   18303032             2
# 24                   positive   18434457            12
# 157                  positive   17562245             1
# 69                   positive   18452197             0
# 33                   positive   18371953             0
# 34                   positive   18371953             7
# 99                   positive   18713852             8
# 166                  positive   18512713             0
# 167                  positive   18512713             1
# 41                   positive   18371953             4
# 159                  positive   18512713             9
# 173                     false   18389682             2
# 11                   positive   17274718             6
# 176                  positive   17945482             8
# 178                  positive   17945482             8
# 55                speculative   18300089            11
# 184                  positive   18790215             5
# 185                  positive   18790215             5
# 187                  positive   18790215             5
# 190                  positive   17697016             8
# 64                   positive   18342498             1
# 194                  positive   18713156             7
# 195                  positive   18713156             5
# 196                  positive   18713156             5
# 197                  positive   18077493             0
# 225                  positive   17291222             0
# 202                     false   17547473             7
# 206                  positive   17726209             5
# 80                      false   18452197             2
# 83                   positive   17167348             8
# 86                      false   17340045             9
# 57                      false   18300089             7
# 216                  positive   18975369             6
# 93                   positive   17989313            10
# 223                  positive   18609261            11
# 97                   positive   18713852            12
# 226                  positive   17291222            10
# 227                     false   17291222             3
# 100                  positive   18713852             8
# 102                  positive   18713852            12
# 107               speculative   18713852            14
# 238               speculative   17244684             1
# 111                  positive   18713852             7
# 240                  positive   17244684             9
# 113                  positive   18713852             7
# 211                  positive   18975369             6
# 122                     false   17894421             1
# 124                     false   17894421            11
# 125                     false   17894421             1
# 126                  negative   19117254            12
#
#                                         subject_text  subject_start  \
# 1      Cardiovascular thromboembolic adverse effects              0
# 3                                    motion sickness            180
# 132                           iron-deficiency anemia            116
# 10                                     periodontitis            128
# 139                            spontaneous abortions            130
# 13                                     periodontitis             91
# 16                                       mild asthma             78
# 17                                       mild asthma             92
# 146                                             PTCL             95
# 147                                             PTCL             95
# 148                                             PTCL             95
# 24                     anterior shoulder dislocation             66
# 157                  high-grade non-Hodgkin lymphoma            179
# 69          colitis-associated colorectal dysplasias             31
# 33                                            glioma             96
# 34                                            glioma            193
# 99                                     aspergillosis            105
# 166                             rheumatoid arthritis             51
# 167                             rheumatoid arthritis             44
# 41                                            glioma            138
# 159                                      lung cancer            140
# 173                                  thromboembolism            210
# 11                               gingival overgrowth             75
# 176                                      lung cancer            213
# 178                                            NSCLC             40
# 55                                      fatal cancer            159
# 184                                immunosuppression            116
# 185                                immunosuppression            116
# 187                                immunosuppression            116
# 190                                          anaemia             47
# 64                                            asthma            105
# 194                                migraine headache             97
# 195                                         headache            158
# 196                                         migraine             81
# 197                                     hypertension             73
# 225                   Pulmonary alveolar proteinosis              0
# 202                           coronary heart disease            159
# 206  stomal varices secondary to portal hypertension             68
# 80                      colitis-associated neoplasia            138
# 83                            cerebrovascular events             33
# 86             noninfectious granulomatous syndromes             37
# 57                               ocular inflammation            155
# 216                                      gout flares             73
# 93                                  multiple myeloma            107
# 223                                       vasculitis            154
# 97                                          diarrhea            119
# 226                                              PAP              0
# 227                              nonproductive cough             82
# 100                       invasive fungal infections             52
# 102                                         vomiting            105
# 107                             resistant infections            163
# 238                                             GVHD            127
# 111                       invasive fungal infections             69
# 240                relapses of gastrointestinal GVHD             18
# 113                       invasive fungal infections             69
# 211                                      gout flares             73
# 122                                 orofacial clefts            156
# 124                                    preterm birth             58
# 125                                 orofacial clefts            156
# 126                                 vascular lesions            100
#
#      subject_end subject_type                                   object_text  \
# 1             45      disease                                cyclooxygenase
# 3            195      disease                                    alfentanil
# 132          138      disease                                     NaFe-EDTA
# 10           141      disease                                           CsA
# 139          151      disease                                 radioisotopes
# 13           104      disease                                           CsA
# 16            89      disease                                   montelukast
# 17           103      disease                                   montelukast
# 146           99      disease                                     cisplatin
# 147           99      disease                                    prednisone
# 148           99      disease                                   vincristine
# 24            95      disease        Intra-articular injection of lidocaine
# 157          210      disease                              cyclophosphamide
# 69            71      disease                         5-aminosalicylic acid
# 33           102      disease                                  indomethacin
# 34           199      disease              indomethacin-loaded nanocapsules
# 99           118      disease                                  itraconazole
# 166           71      disease                                  methotrexate
# 167           64      disease                                  methotrexate
# 41           144      disease  indomethacin ethyl ester-loaded nanocapsules
# 159          151      disease                                  methotrexate
# 173          225      disease                                 anticoagulant
# 11            94      disease                                           CsA
# 176          224      disease                                        sutent
# 178           45      disease                                        sutent
# 55           171      disease                       immunosuppressive drugs
# 184          133      disease                         mycophenolate mofetil
# 185          133      disease                                    tacrolimus
# 187          133      disease                                  cyclosporine
# 190           54      disease                                    Zidovudine
# 64           111      disease                                          ICSs
# 194          114      disease                                    topiramate
# 195          166      disease                                    topiramate
# 196           89      disease                                    topiramate
# 197           85      disease                    medium-dose glucocorticoid
# 225           30      disease                                     sirolimus
# 202          181      disease                                    amlodipine
# 206          115      disease                                silver nitrate
# 80           166      disease                                           DSS
# 83            55      disease                                       Cocaine
# 86            74      disease                                    etanercept
# 57           174      disease                             alkylating agents
# 216           84      disease                                    febuxostat
# 93           123      disease                                          BiRD
# 223          164      disease                              cyclophosphamide
# 97           127      disease                                  posaconazole
# 226            3      disease                                           SRL
# 227          101      disease                                           SRL
# 100           78      disease                                  itraconazole
# 102          113      disease                                  posaconazole
# 107          183      disease                                  posaconazole
# 238          131      disease              oral beclomethasone dipropionate
# 111           95      disease                                  Posaconazole
# 240           51      disease                                    prednisone
# 113           95      disease                                   fluconazole
# 211           84      disease                                   allopurinol
# 122          172      disease                               Benzodiazepines
# 124           71      disease                                           BZD
# 125          172      disease                                           BZD
# 126          116      disease                                  etonogestrel
#
#      object_start  object_end object_type  \
# 1              62          76        drug
# 3              58          68        drug
# 132            67          76        drug
# 10             63          66        drug
# 139            60          73        drug
# 13            145         148        drug
# 16             28          39        drug
# 17            117         128        drug
# 146           270         279        drug
# 147           296         306        drug
# 148           198         209        drug
# 24              0          38        drug
# 157            46          62        drug
# 69              0          21        drug
# 33             26          38        drug
# 34             46          78        drug
# 99            183         195        drug
# 166            94         106        drug
# 167            92         104        drug
# 41             90         134        drug
# 159            38          50        drug
# 173           105         118        drug
# 11             63          66        drug
# 176            88          94        drug
# 178            88          94        drug
# 55             75          98        drug
# 184            56          77        drug
# 185            28          38        drug
# 187            42          54        drug
# 190             0          10        drug
# 64             66          70        drug
# 194            43          53        drug
# 195            14          24        drug
# 196            14          24        drug
# 197            22          48        drug
# 225            61          70        drug
# 202            54          64        drug
# 206           174         188        drug
# 80            125         128        drug
# 83              0           7        drug
# 86             97         107        drug
# 57             48          65        drug
# 216           116         126        drug
# 93              0           4        drug
# 223            83          99        drug
# 97             59          71        drug
# 226            35          38        drug
# 227            27          30        drug
# 100           183         195        drug
# 102            59          71        drug
# 107            14          26        drug
# 238            30          62        drug
# 111             0          12        drug
# 240            74          84        drug
# 113           274         285        drug
# 211           137         148        drug
# 122            12          27        drug
# 124            16          19        drug
# 125            29          32        drug
# 126           141         153        drug
#
#                                      original_sentence data_subset  \
# 1    Cardiovascular thromboembolic adverse effects ...         new
# 3    The frequency of PONV did not correlate to the...         old
# 132  No significant differences were observed betwe...         old
# 10   ET-1 mRNA expression was significantly higher ...         new
# 139  For exposure levels within standard recommende...         new
# 13   Gingival samples were collected from eight nor...         new
# 16   Review of recent results of montelukast use as...         new
# 17   This article reviewed recent results from rand...         new
# 146  Forty-one patients [30 males and 11 females, m...         new
# 147  Forty-one patients [30 males and 11 females, m...         new
# 148  Forty-one patients [30 males and 11 females, m...         old
# 24   Intra-articular injection of lidocaine before ...         new
# 157  Administration of full-dose R-CHOP (rituximab/...         new
# 69   5-aminosalicylic acid inhibits colitis-associa...         new
# 33   Selective cytotoxicity of indomethacin and ind...         new
# 34   The main finding of the present study is that ...         old
# 99   Similarly, the same regimen of posaconazole re...         new
# 166  Incidence of melanoma and other malignancies a...         new
# 167  To determine cancer risk in a cohort of 459 rh...         old
# 41   The aim of this study was to evaluate the effe...         old
# 159  Compared with the general population, methotre...         new
# 173  Dental surgery for these children has historic...         new
# 11   ET-1 mRNA expression was significantly higher ...         new
# 176  Finally, in non-small cell lung cancer (NSCLC)...         new
# 178  Finally, in non-small cell lung cancer (NSCLC)...         new
# 55   Information from the SITE Cohort Study should ...         new
# 184  During the induction phase, tacrolimus or cycl...         new
# 185  During the induction phase, tacrolimus or cycl...         new
# 187  During the induction phase, tacrolimus or cycl...         new
# 190  Zidovudine discontinuation could help to avoid...         new
# 64   There is evidence in the literature that inhal...         new
# 194  This study demonstrated that both low-dose top...         new
# 195  Results - The topiramate group showed a reduct...         new
# 196  Results - The topiramate group showed a reduct...         new
# 197  Long-term exposure to medium-dose glucocortico...         new
# 225  Pulmonary alveolar proteinosis: a rare pulmona...         new
# 202  Compared with both diuretics and contemporary ...         old
# 206  All three patients had recurrent admissions fo...         new
# 80   The chemopreventive activity of 5-ASA was eval...         new
# 83   Cocaine abuse is associated with cerebrovascul...         new
# 86   Recently, there have been reports of noninfect...         new
# 57   Past use of antimetabolites, T-cell inhibitors...         new
# 216  The primary reasons for withdrawal were simila...         new
# 93   BiRD is an effective regimen with manageable s...         new
# 223  Data of our study revealed an unexpected high ...         new
# 97   The most common adverse effects associated wit...         new
# 226  PAP is a very rare complication of SRL therapy...         new
# 227  Two years after initiating SRL, she presented ...         new
# 100  Similarly, the same regimen of posaconazole re...         old
# 102  The most common adverse effects associated wit...         new
# 107  At this time, posaconazole should probably be ...         new
# 238  We tested the hypothesis that oral beclomethas...         old
# 111  Posaconazole, in doses of 200 mg 3 times daily...         new
# 240  Oral BDP prevents relapses of gastrointestinal...         new
# 113  Posaconazole, in doses of 200 mg 3 times daily...         new
# 211  The primary reasons for withdrawal were simila...         new
# 122  Exposure to Benzodiazepines (BZD) during foeta...         new
# 124  Maternal use of BZD and/or HBRA may increase t...         old
# 125  Exposure to Benzodiazepines (BZD) during foeta...         new
# 126  We found no evidence of impaired control of th...         new
#
#                                     formatted_sentence  \
# 1    <div class="formatted_sentence"><span class="s...
# 3    <div class="formatted_sentence">The frequency ...
# 132  <div class="formatted_sentence">No significant...
# 10   <div class="formatted_sentence">ET-1 mRNA expr...
# 139  <div class="formatted_sentence">For exposure l...
# 13   <div class="formatted_sentence">Gingival sampl...
# 16   <div class="formatted_sentence">Review of rece...
# 17   <div class="formatted_sentence">This article r...
# 146  <div class="formatted_sentence">Forty-one pati...
# 147  <div class="formatted_sentence">Forty-one pati...
# 148  <div class="formatted_sentence">Forty-one pati...
# 24   <div class="formatted_sentence"><span class="o...
# 157  <div class="formatted_sentence">Administration...
# 69   <div class="formatted_sentence"><span class="o...
# 33   <div class="formatted_sentence">Selective cyto...
# 34   <div class="formatted_sentence">The main findi...
# 99   <div class="formatted_sentence">Similarly, the...
# 166  <div class="formatted_sentence">Incidence of m...
# 167  <div class="formatted_sentence">To determine c...
# 41   <div class="formatted_sentence">The aim of thi...
# 159  <div class="formatted_sentence">Compared with ...
# 173  <div class="formatted_sentence">Dental surgery...
# 11   <div class="formatted_sentence">ET-1 mRNA expr...
# 176  <div class="formatted_sentence">Finally, in no...
# 178  <div class="formatted_sentence">Finally, in no...
# 55   <div class="formatted_sentence">Information fr...
# 184  <div class="formatted_sentence">During the ind...
# 185  <div class="formatted_sentence">During the ind...
# 187  <div class="formatted_sentence">During the ind...
# 190  <div class="formatted_sentence"><span class="o...
# 64   <div class="formatted_sentence">There is evide...
# 194  <div class="formatted_sentence">This study dem...
# 195  <div class="formatted_sentence">Results - The ...
# 196  <div class="formatted_sentence">Results - The ...
# 197  <div class="formatted_sentence">Long-term expo...
# 225  <div class="formatted_sentence"><span class="s...
# 202  <div class="formatted_sentence">Compared with ...
# 206  <div class="formatted_sentence">All three pati...
# 80   <div class="formatted_sentence">The chemopreve...
# 83   <div class="formatted_sentence"><span class="o...
# 86   <div class="formatted_sentence">Recently, ther...
# 57   <div class="formatted_sentence">Past use of an...
# 216  <div class="formatted_sentence">The primary re...
# 93   <div class="formatted_sentence"><span class="o...
# 223  <div class="formatted_sentence">Data of our st...
# 97   <div class="formatted_sentence">The most commo...
# 226  <div class="formatted_sentence"><span class="s...
# 227  <div class="formatted_sentence">Two years afte...
# 100  <div class="formatted_sentence">Similarly, the...
# 102  <div class="formatted_sentence">The most commo...
# 107  <div class="formatted_sentence">At this time, ...
# 238  <div class="formatted_sentence">We tested the ...
# 111  <div class="formatted_sentence"><span class="o...
# 240  <div class="formatted_sentence">Oral BDP preve...
# 113  <div class="formatted_sentence">Posaconazole, ...
# 211  <div class="formatted_sentence">The primary re...
# 122  <div class="formatted_sentence">Exposure to <s...
# 124  <div class="formatted_sentence">Maternal use o...
# 125  <div class="formatted_sentence">Exposure to Be...
# 126  <div class="formatted_sentence">We found no ev...
#
#                                           form_subject  \
# 1    &quot;<span class="form_subject">Cardiovascula...
# 3    &quot;<span class="form_subject">motion sickne...
# 132  &quot;<span class="form_subject">iron-deficien...
# 10   &quot;<span class="form_subject">periodontitis...
# 139  &quot;<span class="form_subject">spontaneous a...
# 13   &quot;<span class="form_subject">periodontitis...
# 16   &quot;<span class="form_subject">mild asthma</...
# 17   &quot;<span class="form_subject">mild asthma</...
# 146  &quot;<span class="form_subject">PTCL</span>&q...
# 147  &quot;<span class="form_subject">PTCL</span>&q...
# 148  &quot;<span class="form_subject">PTCL</span>&q...
# 24   &quot;<span class="form_subject">anterior shou...
# 157  &quot;<span class="form_subject">high-grade no...
# 69   &quot;<span class="form_subject">colitis-assoc...
# 33   &quot;<span class="form_subject">glioma</span>...
# 34   &quot;<span class="form_subject">glioma</span>...
# 99   &quot;<span class="form_subject">aspergillosis...
# 166  &quot;<span class="form_subject">rheumatoid ar...
# 167  &quot;<span class="form_subject">rheumatoid ar...
# 41   &quot;<span class="form_subject">glioma</span>...
# 159  &quot;<span class="form_subject">lung cancer</...
# 173  &quot;<span class="form_subject">thromboemboli...
# 11   &quot;<span class="form_subject">gingival over...
# 176  &quot;<span class="form_subject">lung cancer</...
# 178  &quot;<span class="form_subject">NSCLC</span>&...
# 55   &quot;<span class="form_subject">fatal cancer<...
# 184  &quot;<span class="form_subject">immunosuppres...
# 185  &quot;<span class="form_subject">immunosuppres...
# 187  &quot;<span class="form_subject">immunosuppres...
# 190  &quot;<span class="form_subject">anaemia</span...
# 64   &quot;<span class="form_subject">asthma</span>...
# 194  &quot;<span class="form_subject">migraine head...
# 195  &quot;<span class="form_subject">headache</spa...
# 196  &quot;<span class="form_subject">migraine</spa...
# 197  &quot;<span class="form_subject">hypertension<...
# 225  &quot;<span class="form_subject">Pulmonary alv...
# 202  &quot;<span class="form_subject">coronary hear...
# 206  &quot;<span class="form_subject">stomal varice...
# 80   &quot;<span class="form_subject">colitis-assoc...
# 83   &quot;<span class="form_subject">cerebrovascul...
# 86   &quot;<span class="form_subject">noninfectious...
# 57   &quot;<span class="form_subject">ocular inflam...
# 216  &quot;<span class="form_subject">gout flares</...
# 93   &quot;<span class="form_subject">multiple myel...
# 223  &quot;<span class="form_subject">vasculitis</s...
# 97   &quot;<span class="form_subject">diarrhea</spa...
# 226  &quot;<span class="form_subject">PAP</span>&quot;
# 227  &quot;<span class="form_subject">nonproductive...
# 100  &quot;<span class="form_subject">invasive fung...
# 102  &quot;<span class="form_subject">vomiting</spa...
# 107  &quot;<span class="form_subject">resistant inf...
# 238  &quot;<span class="form_subject">GVHD</span>&q...
# 111  &quot;<span class="form_subject">invasive fung...
# 240  &quot;<span class="form_subject">relapses of g...
# 113  &quot;<span class="form_subject">invasive fung...
# 211  &quot;<span class="form_subject">gout flares</...
# 122  &quot;<span class="form_subject">orofacial cle...
# 124  &quot;<span class="form_subject">preterm birth...
# 125  &quot;<span class="form_subject">orofacial cle...
# 126  &quot;<span class="form_subject">vascular lesi...
#
#                                            form_object
# 1    &quot;<span class="form_object">cyclooxygenase...
# 3    &quot;<span class="form_object">alfentanil</sp...
# 132  &quot;<span class="form_object">NaFe-EDTA</spa...
# 10    &quot;<span class="form_object">CsA</span>&quot;
# 139  &quot;<span class="form_object">radioisotopes<...
# 13    &quot;<span class="form_object">CsA</span>&quot;
# 16   &quot;<span class="form_object">montelukast</s...
# 17   &quot;<span class="form_object">montelukast</s...
# 146  &quot;<span class="form_object">cisplatin</spa...
# 147  &quot;<span class="form_object">prednisone</sp...
# 148  &quot;<span class="form_object">vincristine</s...
# 24   &quot;<span class="form_object">Intra-articula...
# 157  &quot;<span class="form_object">cyclophosphami...
# 69   &quot;<span class="form_object">5-aminosalicyl...
# 33   &quot;<span class="form_object">indomethacin</...
# 34   &quot;<span class="form_object">indomethacin-l...
# 99   &quot;<span class="form_object">itraconazole</...
# 166  &quot;<span class="form_object">methotrexate</...
# 167  &quot;<span class="form_object">methotrexate</...
# 41   &quot;<span class="form_object">indomethacin e...
# 159  &quot;<span class="form_object">methotrexate</...
# 173  &quot;<span class="form_object">anticoagulant<...
# 11    &quot;<span class="form_object">CsA</span>&quot;
# 176  &quot;<span class="form_object">sutent</span>&...
# 178  &quot;<span class="form_object">sutent</span>&...
# 55   &quot;<span class="form_object">immunosuppress...
# 184  &quot;<span class="form_object">mycophenolate ...
# 185  &quot;<span class="form_object">tacrolimus</sp...
# 187  &quot;<span class="form_object">cyclosporine</...
# 190  &quot;<span class="form_object">Zidovudine</sp...
# 64   &quot;<span class="form_object">ICSs</span>&quot;
# 194  &quot;<span class="form_object">topiramate</sp...
# 195  &quot;<span class="form_object">topiramate</sp...
# 196  &quot;<span class="form_object">topiramate</sp...
# 197  &quot;<span class="form_object">medium-dose gl...
# 225  &quot;<span class="form_object">sirolimus</spa...
# 202  &quot;<span class="form_object">amlodipine</sp...
# 206  &quot;<span class="form_object">silver nitrate...
# 80    &quot;<span class="form_object">DSS</span>&quot;
# 83   &quot;<span class="form_object">Cocaine</span>...
# 86   &quot;<span class="form_object">etanercept</sp...
# 57   &quot;<span class="form_object">alkylating age...
# 216  &quot;<span class="form_object">febuxostat</sp...
# 93   &quot;<span class="form_object">BiRD</span>&quot;
# 223  &quot;<span class="form_object">cyclophosphami...
# 97   &quot;<span class="form_object">posaconazole</...
# 226   &quot;<span class="form_object">SRL</span>&quot;
# 227   &quot;<span class="form_object">SRL</span>&quot;
# 100  &quot;<span class="form_object">itraconazole</...
# 102  &quot;<span class="form_object">posaconazole</...
# 107  &quot;<span class="form_object">posaconazole</...
# 238  &quot;<span class="form_object">oral beclometh...
# 111  &quot;<span class="form_object">Posaconazole</...
# 240  &quot;<span class="form_object">prednisone</sp...
# 113  &quot;<span class="form_object">fluconazole</s...
# 211  &quot;<span class="form_object">allopurinol</s...
# 122  &quot;<span class="form_object">Benzodiazepine...
# 124   &quot;<span class="form_object">BZD</span>&quot;
# 125   &quot;<span class="form_object">BZD</span>&quot;
# 126  &quot;<span class="form_object">etonogestrel</...

# %%
work_units.to_csv("data/work_units_for_cf.tsv", sep = "\t", index = False)
